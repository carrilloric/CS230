# %% [markdown]
# # Google Drive Setup

# %%
# Previous Check to have a GPU available
# Make sure that you have GPU selected in the Runtime
# If you do, will print Found GPU at: /device:GPU:0
# Else go to Runtime -> Change Runtime Type

import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Found GPU at: /device:GPU:0

# %%
# GOOGLE DRIVE - COLAB
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
# drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)

# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# googlepath exists for googledrive finding the files. Can be set to empty 
# string if running on computer. Have companylist.csv in same dir. Will create
# a stock_data folder and download stocks data into that. 
googlepath = "drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/"

# Setting the Training Amount
TRAINING_AMOUNT = 50000 # low to test for now
SAVE_STEPS_AMOUNT = 10000 # testing for now
PCT_CHANGE_AMOUNT = 0.001 # just want to see up down trends ORIGINAL 5
HISTORICAL_DAYS_AMOUNT = 20
DAYS_AHEAD = 1 # ORIGINAL 5

# %% [markdown]
# # Getting the Data
# Currently set to just download stock on first row of companylist.csv (aka AAPL) and saves it to the stock_data folder

# %%
'''
Downloads stock data from alphavantage
'''
import pandas as pd 
import os
import time
import urllib
import json
import csv
import requests
import io
from pathlib import Path
import random

ALPHA_VANTAGE_KEY = "3RZHI30EBWV3VN9R"

'''
Note should have companylist.csv in the directory with this file.
'''

'''
Saves data to a file
'''
def save(googlepath, stock_csv, output_dir, filename):
    try:
        #the output dir may not exist
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
    except Exception as ex:
        print('Could not create output dir')
        print(ex)
        return
    filepath = os.path.join(googlepath, output_dir, filename)
    try:
#         print(stock_csv)
        df = stock_csv
        df = df.sort_values(by='timestamp')  
#         print(df)
        df.to_csv(filepath, index=False)
    except Exception as ex:
        print('Could not open file {} to write data'.format(filepath))
        print(ex)


def try_download(symbol):
    try:
        # Keep call frequency below threshold 
        time.sleep(12)    
        url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={}&apikey={}&datatype=csv&outputsize=full'.format(symbol, ALPHA_VANTAGE_KEY)
        c = pd.read_csv(url)
        # getting rid of some columns won't look at for now
        c = c.drop(['split_coefficient', 'dividend_amount', 'adjusted_close'], axis=1)
        return c, True
    except Exception as ex:
        print(ex)
        return None, None



#Given a stock symbol (aka 'tsla') will download and save the data to the
#output dir as a csv 

def download_symbol(symbol, output_dir, retry_count=4):

    stock_csv, didPass = try_download(symbol)
    if didPass:
        save(googlepath, stock_csv, output_dir, '{}.csv'.format(symbol))
    else:
        print('Failed to download {}'.format(symbol))

df = pd.read_csv(f"{googlepath}companylist.csv")
# df = df.sort_values(by=['MarketCap'], ascending=False)
# Top 30 Companies
# df = df[:30]
for symbol in df.Symbol:
    my_file = Path(f"{googlepath}stock_data/{symbol}.csv")  # check if already downloaded
#     print(my_file.exists())
    if not my_file.exists():
        print('Downloading {}'.format(symbol))
        download_symbol(symbol, 'stock_data')
    else:
        print(f"Already downloaded {symbol}")
# Out:
# Already downloaded MMM
# Already downloaded AOS
# Already downloaded ABT
# Already downloaded ABBV
# Already downloaded ACN
# Already downloaded ATVI
# Already downloaded AYI
# Already downloaded ADBE
# Already downloaded AAP
# Already downloaded AMD
# Already downloaded AES
# Already downloaded AET
# Already downloaded AMG
# Already downloaded AFL
# Already downloaded A
# Already downloaded APD
# Already downloaded AKAM
# Already downloaded ALK
# Already downloaded ALB
# Already downloaded ARE
# Already downloaded ALXN
# Already downloaded ALGN
# Already downloaded ALLE
# Already downloaded AGN
# Already downloaded ADS
# Already downloaded LNT
# Already downloaded ALL
# Already downloaded GOOGL
# Already downloaded GOOG
# Already downloaded MO
# Already downloaded AMZN
# Already downloaded AEE
# Already downloaded AAL
# Already downloaded AEP
# Already downloaded AXP
# Already downloaded AIG
# Already downloaded AMT
# Already downloaded AWK
# Already downloaded AMP
# Already downloaded ABC
# Already downloaded AME
# Already downloaded AMGN
# Already downloaded APH
# Already downloaded APC
# Already downloaded ADI
# Already downloaded ANDV
# Already downloaded ANSS
# Already downloaded ANTM
# Already downloaded AON
# Already downloaded APA
# Already downloaded AIV
# Already downloaded AAPL
# Already downloaded AMAT
# Already downloaded APTV
# Already downloaded ADM
# Already downloaded ARNC
# Already downloaded AJG
# Already downloaded AIZ
# Already downloaded T
# Already downloaded ADSK
# Already downloaded ADP
# Already downloaded AZO
# Already downloaded AVB
# Already downloaded AVY
# Already downloaded BHGE
# Already downloaded BLL
# Already downloaded BAC
# Already downloaded BAX
# Already downloaded BBT
# Already downloaded BDX
# Already downloaded BRK.B
# Already downloaded BBY
# Already downloaded BIIB
# Already downloaded BLK
# Already downloaded HRB
# Already downloaded BA
# Already downloaded BKNG
# Already downloaded BWA
# Already downloaded BXP
# Already downloaded BSX
# Already downloaded BHF
# Already downloaded BMY
# Already downloaded AVGO
# Already downloaded CHRW
# Already downloaded CA
# Already downloaded COG
# Already downloaded CDNS
# Already downloaded CPB
# Already downloaded COF
# Already downloaded CAH
# Already downloaded KMX
# Already downloaded CCL
# Already downloaded CAT
# Already downloaded CBOE
# Already downloaded CBRE
# Already downloaded CBS
# Already downloaded CELG
# Already downloaded CNC
# Already downloaded CNP
# Already downloaded CTL
# Already downloaded CERN
# Already downloaded CF
# Already downloaded SCHW
# Already downloaded CHTR
# Already downloaded CVX
# Already downloaded CMG
# Already downloaded CB
# Already downloaded CHD
# Already downloaded CI
# Already downloaded XEC
# Already downloaded CINF
# Already downloaded CTAS
# Already downloaded CSCO
# Already downloaded C
# Already downloaded CFG
# Already downloaded CTXS
# Already downloaded CME
# Already downloaded CMS
# Already downloaded KO
# Already downloaded CTSH
# Already downloaded CL
# Already downloaded CMCSA
# Already downloaded CMA
# Already downloaded CAG
# Already downloaded CXO
# Already downloaded COP
# Already downloaded ED
# Already downloaded STZ
# Already downloaded GLW
# Already downloaded COST
# Already downloaded COTY
# Already downloaded CCI
# Already downloaded CSRA
# Already downloaded CSX
# Already downloaded CMI
# Already downloaded CVS
# Already downloaded DHI
# Already downloaded DHR
# Already downloaded DRI
# Already downloaded DVA
# Already downloaded DE
# Already downloaded DAL
# Already downloaded XRAY
# Already downloaded DVN
# Already downloaded DLR
# Already downloaded DFS
# Already downloaded DISCA
# Already downloaded DISCK
# Already downloaded DISH
# Already downloaded DG
# Already downloaded DLTR
# Already downloaded D
# Already downloaded DOV
# Already downloaded DWDP
# Already downloaded DPS
# Already downloaded DTE
# Already downloaded DUK
# Already downloaded DRE
# Already downloaded DXC
# Already downloaded ETFC
# Already downloaded EMN
# Already downloaded ETN
# Already downloaded EBAY
# Already downloaded ECL
# Already downloaded EIX
# Already downloaded EW
# Already downloaded EA
# Already downloaded EMR
# Already downloaded ETR
# Already downloaded EVHC
# Already downloaded EOG
# Already downloaded EQT
# Already downloaded EFX
# Already downloaded EQIX
# Already downloaded EQR
# Already downloaded ESS
# Already downloaded EL
# Already downloaded RE
# Already downloaded ES
# Already downloaded EXC
# Already downloaded EXPE
# Already downloaded EXPD
# Already downloaded ESRX
# Already downloaded EXR
# Already downloaded XOM
# Already downloaded FFIV
# Already downloaded FB
# Already downloaded FAST
# Already downloaded FRT
# Already downloaded FDX
# Already downloaded FIS
# Already downloaded FITB
# Already downloaded FE
# Already downloaded FISV
# Already downloaded FLIR
# Already downloaded FLS
# Already downloaded FLR
# Already downloaded FMC
# Already downloaded FL
# Already downloaded F
# Already downloaded FTV
# Already downloaded FBHS
# Already downloaded BEN
# Already downloaded FCX
# Already downloaded GPS
# Already downloaded GRMN
# Already downloaded IT
# Already downloaded GD
# Already downloaded GE
# Already downloaded GGP
# Already downloaded GIS
# Already downloaded GM
# Already downloaded GPC
# Already downloaded GILD
# Already downloaded GPN
# Already downloaded GS
# Already downloaded GT
# Already downloaded GWW
# Already downloaded HAL
# Already downloaded HBI
# Already downloaded HOG
# Already downloaded HRS
# Already downloaded HIG
# Already downloaded HAS
# Already downloaded HCA
# Already downloaded HCP
# Already downloaded HP
# Already downloaded HSIC
# Already downloaded HES
# Already downloaded HPE
# Already downloaded HLT
# Already downloaded HOLX
# Already downloaded HD
# Already downloaded HON
# Already downloaded HRL
# Already downloaded HST
# Already downloaded HPQ
# Already downloaded HUM
# Already downloaded HBAN
# Already downloaded HII
# Already downloaded IDXX
# Already downloaded INFO
# Already downloaded ITW
# Already downloaded ILMN
# Already downloaded INCY
# Already downloaded IR
# Already downloaded INTC
# Already downloaded ICE
# Already downloaded IBM
# Already downloaded IP
# Already downloaded IPG
# Already downloaded IFF
# Already downloaded INTU
# Already downloaded ISRG
# Already downloaded IVZ
# Already downloaded IPGP
# Already downloaded IQV
# Already downloaded IRM
# Already downloaded JBHT
# Already downloaded JEC
# Already downloaded SJM
# Already downloaded JNJ
# Already downloaded JCI
# Already downloaded JPM
# Already downloaded JNPR
# Already downloaded KSU
# Already downloaded K
# Already downloaded KEY
# Already downloaded KMB
# Already downloaded KIM
# Already downloaded KMI
# Already downloaded KLAC
# Already downloaded KSS
# Already downloaded KHC
# Already downloaded KR
# Already downloaded LB
# Already downloaded LLL
# Already downloaded LH
# Already downloaded LRCX
# Already downloaded LEG
# Already downloaded LEN
# Already downloaded LUK
# Already downloaded LLY
# Already downloaded LNC
# Already downloaded LKQ
# Already downloaded LMT
# Already downloaded L
# Already downloaded LOW
# Already downloaded LYB
# Already downloaded MTB
# Already downloaded MAC
# Already downloaded M
# Already downloaded MRO
# Already downloaded MPC
# Already downloaded MAR
# Already downloaded MMC
# Already downloaded MLM
# Already downloaded MAS
# Already downloaded MA
# Already downloaded MAT
# Already downloaded MKC
# Already downloaded MCD
# Already downloaded MCK
# Already downloaded MDT
# Already downloaded MRK
# Already downloaded MET
# Already downloaded MTD
# Already downloaded MGM
# Already downloaded KORS
# Already downloaded MCHP
# Already downloaded MU
# Already downloaded MSFT
# Already downloaded MAA
# Already downloaded MHK
# Already downloaded TAP
# Already downloaded MDLZ
# Already downloaded MON
# Already downloaded MNST
# Already downloaded MCO
# Already downloaded MS
# Already downloaded MSI
# Already downloaded MYL
# Already downloaded NDAQ
# Already downloaded NOV
# Already downloaded NAVI
# Already downloaded NKTR
# Already downloaded NTAP
# Already downloaded NFLX
# Already downloaded NWL
# Already downloaded NFX
# Already downloaded NEM
# Already downloaded NWSA
# Already downloaded NWS
# Already downloaded NEE
# Already downloaded NLSN
# Already downloaded NKE
# Already downloaded NI
# Already downloaded NBL
# Already downloaded JWN
# Already downloaded NSC
# Already downloaded NTRS
# Already downloaded NOC
# Already downloaded NCLH
# Already downloaded NRG
# Already downloaded NUE
# Already downloaded NVDA
# Already downloaded ORLY
# Already downloaded OXY
# Already downloaded OMC
# Already downloaded OKE
# Already downloaded ORCL
# Already downloaded PCAR
# Already downloaded PKG
# Already downloaded PH
# Already downloaded PAYX
# Already downloaded PYPL
# Already downloaded PNR
# Already downloaded PBCT
# Already downloaded PEP
# Already downloaded PKI
# Already downloaded PRGO
# Already downloaded PFE
# Already downloaded PCG
# Already downloaded PM
# Already downloaded PSX
# Already downloaded PNW
# Already downloaded PXD
# Already downloaded PNC
# Already downloaded RL
# Already downloaded PPG
# Already downloaded PPL
# Already downloaded PX
# Already downloaded PFG
# Already downloaded PG
# Already downloaded PGR
# Already downloaded PLD
# Already downloaded PRU
# Already downloaded PEG
# Already downloaded PSA
# Already downloaded PHM
# Already downloaded PVH
# Already downloaded QRVO
# Already downloaded QCOM
# Already downloaded PWR
# Already downloaded DGX
# Already downloaded RRC
# Already downloaded RJF
# Already downloaded RTN
# Already downloaded O
# Already downloaded RHT
# Already downloaded REG
# Already downloaded REGN
# Already downloaded RF
# Already downloaded RSG
# Already downloaded RMD
# Already downloaded RHI
# Already downloaded ROK
# Already downloaded COL
# Already downloaded ROP
# Already downloaded ROST
# Already downloaded RCL
# Already downloaded SPGI
# Already downloaded CRM
# Already downloaded SBAC
# Already downloaded SCG
# Already downloaded SLB
# Already downloaded STX
# Already downloaded SEE
# Already downloaded SRE
# Already downloaded SHW
# Already downloaded SPG
# Already downloaded SWKS
# Already downloaded SLG
# Already downloaded SNA
# Already downloaded SO
# Already downloaded LUV
# Already downloaded SWK
# Already downloaded SBUX
# Already downloaded STT
# Already downloaded SRCL
# Already downloaded SYK
# Already downloaded STI
# Already downloaded SIVB
# Already downloaded SYMC
# Already downloaded SYF
# Already downloaded SNPS
# Already downloaded SYY
# Already downloaded TROW
# Already downloaded TTWO
# Already downloaded TPR
# Already downloaded TGT
# Already downloaded TEL
# Already downloaded FTI
# Already downloaded TXN
# Already downloaded TXT
# Already downloaded BK
# Already downloaded CLX
# Already downloaded COO
# Already downloaded HSY
# Already downloaded MOS
# Already downloaded TRV
# Already downloaded DIS
# Already downloaded TMO
# Already downloaded TIF
# Already downloaded TWX
# Already downloaded TJX
# Already downloaded TMK
# Already downloaded TSS
# Already downloaded TSCO
# Already downloaded TDG
# Already downloaded TRIP
# Already downloaded FOXA
# Already downloaded FOX
# Already downloaded TSN
# Already downloaded USB
# Already downloaded UDR
# Already downloaded ULTA
# Already downloaded UAA
# Already downloaded UA
# Already downloaded UNP
# Already downloaded UAL
# Already downloaded UNH
# Already downloaded UPS
# Already downloaded URI
# Already downloaded UTX
# Already downloaded UHS
# Already downloaded UNM
# Already downloaded VFC
# Already downloaded VLO
# Already downloaded VAR
# Already downloaded VTR
# Already downloaded VRSN
# Already downloaded VRSK
# Already downloaded VZ
# Already downloaded VRTX
# Already downloaded VIAB
# Already downloaded V
# Already downloaded VNO
# Already downloaded VMC
# Already downloaded WMT
# Already downloaded WBA
# Already downloaded WM
# Already downloaded WAT
# Already downloaded WEC
# Already downloaded WFC
# Already downloaded WELL
# Already downloaded WDC
# Already downloaded WU
# Already downloaded WRK
# Already downloaded WY
# Already downloaded WHR
# Already downloaded WMB
# Already downloaded WLTW
# Already downloaded WYN
# Already downloaded WYNN
# Already downloaded XEL
# Already downloaded XRX
# Already downloaded XLNX
# Already downloaded XL
# Already downloaded XYL
# Already downloaded YUM
# Already downloaded ZBH
# Already downloaded ZION
# Already downloaded ZTS

# %% [markdown]
# # Define the Confusion Matrix

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.ylim([1.5, -.5])


    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    #thresh = cm.max() / 2. # Previous
    fmt = '.4f' if normalize else 'd'
    thresh = cm.max() - 0.05

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        #print (cm[i, j])
        plt.text(j, i, format(cm[i, j],fmt),
                 horizontalalignment="center",
                 fontsize=24, 
                 color="white" if cm[i, j] > thresh else "black")

    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    #    plt.text(j, i, cm[i, j],
    #             horizontalalignment="center",
    #             color="black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# # Initializing the GAN

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

SEED = 42
tf.set_random_seed(SEED)

class GAN():

    def sample_Z(self, batch_size, n):
        return np.random.uniform(-1., 1., size=(batch_size, n))

    def __init__(self, num_features, num_historical_days, generator_input_size=200, is_train=True):
        def get_batch_norm_with_global_normalization_vars(size):
            v = tf.Variable(tf.ones([size]), dtype=tf.float32)
            m = tf.Variable(tf.ones([size]), dtype=tf.float32)
            beta = tf.Variable(tf.ones([size]), dtype=tf.float32)
            gamma = tf.Variable(tf.ones([size]), dtype=tf.float32)
            return v, m, beta, gamma

        self.X = tf.placeholder(tf.float32, shape=[None, num_historical_days, num_features])
        X = tf.reshape(self.X, [-1, num_historical_days, 1, num_features])
        self.Z = tf.placeholder(tf.float32, shape=[None, generator_input_size])

        generator_output_size = num_features*num_historical_days
        with tf.variable_scope("generator"):
            W1 = tf.Variable(tf.truncated_normal([generator_input_size, generator_output_size*10]))
            b1 = tf.Variable(tf.truncated_normal([generator_output_size*10]))

            h1 = tf.nn.sigmoid(tf.matmul(self.Z, W1) + b1)

            # v1, m1, beta1, gamma1 = get_batch_norm_with_global_normalization_vars(generator_output_size*10)
            # h1 = tf.nn.batch_norm_with_global_normalization(h1, v1, m1,
            #         beta1, gamma1, variance_epsilon=0.000001, scale_after_normalization=False)

            W2 = tf.Variable(tf.truncated_normal([generator_output_size*10, generator_output_size*5]))
            b2 = tf.Variable(tf.truncated_normal([generator_output_size*5]))

            h2 = tf.nn.sigmoid(tf.matmul(h1, W2) + b2)

            # v2, m2, beta2, gamma2 = get_batch_norm_with_global_normalization_vars(generator_output_size*5)
            # h2 = tf.nn.batch_norm_with_global_normalization(h2, v2, m2,
            #         beta2, gamma2, variance_epsilon=0.000001, scale_after_normalization=False)


            W3 = tf.Variable(tf.truncated_normal([generator_output_size*5, generator_output_size]))
            b3 = tf.Variable(tf.truncated_normal([generator_output_size]))

            g_log_prob = tf.matmul(h2, W3) + b3
            g_log_prob = tf.reshape(g_log_prob, [-1, num_historical_days, 1, num_features])
            self.gen_data = tf.reshape(g_log_prob, [-1, num_historical_days, num_features])
            #g_log_prob = g_log_prob / tf.reshape(tf.reduce_max(g_log_prob, axis=1), [-1, 1, num_features, 1])
            #g_prob = tf.nn.sigmoid(g_log_prob)

            theta_G = [W1, b1, W2, b2, W3, b3]



        with tf.variable_scope("discriminator"):
            #[filter_height, filter_width, in_channels, out_channels]
            k1 = tf.Variable(tf.truncated_normal([3, 1, num_features, 32],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b1 = tf.Variable(tf.zeros([32], dtype=tf.float32))

            v1, m1, beta1, gamma1 = get_batch_norm_with_global_normalization_vars(32)

            k2 = tf.Variable(tf.truncated_normal([3, 1, 32, 64],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b2 = tf.Variable(tf.zeros([64], dtype=tf.float32))

            v2, m2, beta2, gamma2 = get_batch_norm_with_global_normalization_vars(64)

            k3 = tf.Variable(tf.truncated_normal([3, 1, 64, 128],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b3 = tf.Variable(tf.zeros([128], dtype=tf.float32))

            v3, m3, beta3, gamma3 = get_batch_norm_with_global_normalization_vars(128)

            W1 = tf.Variable(tf.truncated_normal([18*1*128, 128]))
            b4 = tf.Variable(tf.truncated_normal([128]))

            v4, m4, beta4, gamma4 = get_batch_norm_with_global_normalization_vars(128)

            W2 = tf.Variable(tf.truncated_normal([128, 1]))

            theta_D = [k1, b1, k2, b2, k3, b3, W1, b4, W2]

        def discriminator(X):
            conv = tf.nn.conv2d(X,k1,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b1))
            pool = relu
            # pool = tf.nn.avg_pool(relu, ksize=[1, 2, 1, 1], strides=[1, 2, 1, 1], padding='SAME')
            if is_train:
                pool = tf.nn.dropout(pool, keep_prob = 0.8)
            # pool = tf.nn.batch_norm_with_global_normalization(pool, v1, m1,
            #         beta1, gamma1, variance_epsilon=0.000001, scale_after_normalization=False)
            print(pool)

            conv = tf.nn.conv2d(pool, k2,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b2))
            pool = relu
            #pool = tf.nn.avg_pool(relu, ksize=[1, 2, 1, 1], strides=[1, 2, 1, 1], padding='SAME')
            if is_train:
                pool = tf.nn.dropout(pool, keep_prob = 0.8)
            # pool = tf.nn.batch_norm_with_global_normalization(pool, v2, m2,
            #         beta2, gamma2, variance_epsilon=0.000001, scale_after_normalization=False)
            print(pool)

            conv = tf.nn.conv2d(pool, k3, strides=[1, 1, 1, 1], padding='VALID')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b3))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob=0.8)
            # relu = tf.nn.batch_norm_with_global_normalization(relu, v3, m3,
            #         beta3, gamma3, variance_epsilon=0.000001, scale_after_normalization=False)
            print(relu)


            flattened_convolution_size = int(relu.shape[1]) * int(relu.shape[2]) * int(relu.shape[3])
            print(flattened_convolution_size)
            flattened_convolution = features = tf.reshape(relu, [-1, flattened_convolution_size])

            if is_train:
                flattened_convolution =  tf.nn.dropout(flattened_convolution, keep_prob=0.8)

            h1 = tf.nn.relu(tf.matmul(flattened_convolution, W1) + b4)

            # h1 = tf.nn.batch_norm_with_global_normalization(h1, v4, m4,
            #         beta4, gamma4, variance_epsilon=0.000001, scale_after_normalization=False)

            D_logit = tf.matmul(h1, W2)
            D_prob = tf.nn.sigmoid(D_logit)
            return D_prob, D_logit, features

        D_real, D_logit_real, self.features = discriminator(X)
        D_fake, D_logit_fake, _ = discriminator(g_log_prob)


        D_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_real, labels=tf.ones_like(D_logit_real)))
        D_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.zeros_like(D_logit_fake)))
        self.D_l2_loss = (0.0001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_D]) / len(theta_D))
        self.D_loss = D_loss_real + D_loss_fake + self.D_l2_loss
        self.G_l2_loss = (0.00001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_G]) / len(theta_G))
        self.G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.ones_like(D_logit_fake))) + self.G_l2_loss


        self.D_solver = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(self.D_loss, var_list=theta_D)
        self.G_solver = tf.train.AdamOptimizer(learning_rate=0.000055).minimize(self.G_loss, var_list=theta_G)

# %% [markdown]
# # Training the GAN

# %%
import os
import pandas as pd
# from gan import GAN
import random
import tensorflow as tf

random.seed(42)
class TrainGan:

    def __init__(self, num_historical_days, batch_size=128):
        self.batch_size = batch_size
        self.data = []
#         files = [os.path.join('./stock_data', f) for f in os.listdir('./stock_data')]

        # Google Drive Method
        files = [f"{googlepath}stock_data/{f}" for f in os.listdir(f"{googlepath}stock_data")]
#         print(files)
      
        for file in files:
            print(file)
            #Read in file -- note that parse_dates will be need later
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open','high','low','close','volume']]
            # #Create new index with missing days
            # idx = pd.date_range(df.index[-1], df.index[0])
            # #Reindex and fill the missing day with the value from the day before
            # df = df.reindex(idx, method='bfill').sort_index(ascending=False)
            #Normilize using a of size num_historical_days
            df = ((df -
            df.rolling(num_historical_days).mean().shift(-num_historical_days))
            /(df.rolling(num_historical_days).max().shift(-num_historical_days)
            -df.rolling(num_historical_days).min().shift(-num_historical_days)))
            #Drop the last 10 day that we don't have data for
            df = df.dropna()
            #Hold out the last year of trading for testing
            #Padding to keep labels from bleeding
            df = df[400:]
            #This may not create good samples if num_historical_days is a
            #mutliple of 7
            for i in range(num_historical_days, len(df), num_historical_days):
                self.data.append(df.values[i-num_historical_days:i])

        self.gan = GAN(num_features=5, num_historical_days=num_historical_days,
                        generator_input_size=200)

    def random_batch(self, batch_size=128):
        batch = []
        while True:
            batch.append(random.choice(self.data))
            if (len(batch) == batch_size):
                yield batch
                batch = []

    def train(self, print_steps=100, display_data=100, save_steps=SAVE_STEPS_AMOUNT):
        if not os.path.exists(f'{googlepath}models'):
            os.makedirs(f'{googlepath}models')
        sess = tf.Session()
        
        G_loss = 0
        D_loss = 0
        G_l2_loss = 0
        D_l2_loss = 0
        sess.run(tf.global_variables_initializer())
        saver = tf.train.Saver()
        currentStep = "0"
        
        g_loss_array = []
        d_loss_array = []
        
        if os.path.exists(f'{googlepath}models/checkpoint'):
                with open(f'{googlepath}models/checkpoint', 'rb') as f:
                    model_name = next(f).split('"'.encode())[1]
                filename = "{}models/{}".format(googlepath, model_name.decode())
                currentStep = filename.split("-")[1]
                new_saver = tf.train.import_meta_graph('{}.meta'.format(filename))
                new_saver.restore(sess, "{}".format(filename))

        for i, X in enumerate(self.random_batch(self.batch_size)):

            
            
            
            if i % 1 == 0:
                _, D_loss_curr, D_l2_loss_curr = sess.run([self.gan.D_solver, self.gan.D_loss, self.gan.D_l2_loss], feed_dict=
                        {self.gan.X:X, self.gan.Z:self.gan.sample_Z(self.batch_size, 200)})
                D_loss += D_loss_curr
                D_l2_loss += D_l2_loss_curr
            if i % 1 == 0:
                _, G_loss_curr, G_l2_loss_curr = sess.run([self.gan.G_solver, self.gan.G_loss, self.gan.G_l2_loss],
                        feed_dict={self.gan.Z:self.gan.sample_Z(self.batch_size, 200)})
                G_loss += G_loss_curr
                G_l2_loss += G_l2_loss_curr
                
            g_loss_array.append(G_loss_curr - G_l2_loss)
            d_loss_array.append(D_loss_curr - D_l2_loss)
            
            
            if (i+1) % print_steps == 0:
                print('Step={} D_loss={}, G_loss={}'.format(i + int(currentStep), D_loss/print_steps - D_l2_loss/print_steps, G_loss/print_steps - G_l2_loss/print_steps))
                #print('D_l2_loss = {} G_l2_loss={}'.format(D_l2_loss/print_steps, G_l2_loss/print_steps))
                G_loss = 0
                D_loss = 0
                G_l2_loss = 0
                D_l2_loss = 0
            if (i+1) % save_steps == 0:
                saver.save(sess, f'{googlepath}/models/gan.ckpt', i + int(currentStep))
            
            # end training at training_amount epochs
            if ((i + int(currentStep)) > TRAINING_AMOUNT):
                
                print("Reached {} epochs for GAN".format(i + int(currentStep)))
                sess.close()
                
                axisX = np.arange(0,len(g_loss_array),1)
                plt.plot(axisX, g_loss_array, label='generator loss')
                plt.plot(axisX, d_loss_array, label='discriminator loss')
                plt.legend()
                plt.title('generator and discriminator loss')
                plt.show()
                
                break

            # if (i+1) % display_data == 0:
            #     print('Generated Data')
            #     print(sess.run(self.gan.gen_data, feed_dict={self.gan.Z:self.gan.sample_Z(1, 200)}))
            #     print('Real Data')
            #     print(X[0])


# if __name__ == '__main__':
tf.reset_default_graph()
gan = TrainGan(HISTORICAL_DAYS_AMOUNT, 128)
gan.train()
# Out:
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANDV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANTM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AJG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/T.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AZO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHGE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BRK.B.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BIIB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BKNG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BWA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BMY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHRW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CDNS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CPB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBOE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CELG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CERN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CINF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/C.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTXS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTSH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMCSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CXO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ED.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GLW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COTY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSRA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DFS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/D.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DWDP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DTE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EBAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ECL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EVHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FFIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FAST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FRT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FITB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FISV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLIR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/F.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FBHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GRMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GILD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GWW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSIC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HLT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBAN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HII.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IDXX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INFO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ITW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ILMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INCY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ICE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IBM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IFF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ISRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IVZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IQV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JBHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SJM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNJ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JPM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/K.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KEY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KIM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KLAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LRCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LKQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/L.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LOW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LYB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/M.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MLM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MKC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MGM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KORS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCHP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSFT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MHK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDLZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MNST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NDAQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NAVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NLSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NBL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JWN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NSC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NCLH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NUE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NVDA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OXY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PAYX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PYPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PBCT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PXD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PGR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PLD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PHM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PVH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QRVO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QCOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PWR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DGX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RRC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RJF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RTN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/O.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RSG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPGI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWKS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBUX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SIVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TROW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TTWO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TGT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TIF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TWX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TJX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TDG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRIP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOXA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/USB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UDR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ULTA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/URI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VLO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VIAB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/V.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VNO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WBA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WELL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WDC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WLTW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYNN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XLNX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/YUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZBH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZION.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZTS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABBV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ACN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ATVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AYI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADBE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AFL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/A.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AKAM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALLE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOGL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMZN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADI.csv
# WARNING:tensorflow:From <ipython-input-6-e2f54d100762>:95: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Tensor("dropout/mul_1:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("dropout_1/mul_1:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("dropout_2/mul_1:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# Tensor("dropout_4/mul_1:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("dropout_5/mul_1:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("dropout_6/mul_1:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/models/gan.ckpt-49999
# Reached 50001 epochs for GAN

# %% [markdown]
# # Initializing the CNN

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

SEED = 42
tf.set_random_seed(SEED)
class CNN():

    def __init__(self, num_features, num_historical_days, is_train=True):
      
        self.X = tf.placeholder(tf.float32, shape=[None, num_historical_days, num_features])
        X = tf.reshape(self.X, [-1, num_historical_days, 1, num_features])
        self.Y = tf.placeholder(tf.int32, shape=[None, 2])
        self.keep_prob = tf.placeholder(tf.float32, shape=[])

        with tf.variable_scope("cnn"):
            #[filter_height, filter_width, in_channels, out_channels]
            k1 = tf.Variable(tf.truncated_normal([3, 1, num_features, 16],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b1 = tf.Variable(tf.zeros([16], dtype=tf.float32))

            conv = tf.nn.conv2d(X,k1,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b1))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob = self.keep_prob)
            print(relu)


            k2 = tf.Variable(tf.truncated_normal([3, 1, 16, 32],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b2 = tf.Variable(tf.zeros([32], dtype=tf.float32))
            conv = tf.nn.conv2d(relu, k2,strides=[1, 1, 1, 1],padding='SAME')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b2))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob = self.keep_prob)
            print(relu)


            k3 = tf.Variable(tf.truncated_normal([3, 1, 32, 64],
                stddev=0.1,seed=SEED, dtype=tf.float32))
            b3 = tf.Variable(tf.zeros([64], dtype=tf.float32))
            conv = tf.nn.conv2d(relu, k3, strides=[1, 1, 1, 1], padding='VALID')
            relu = tf.nn.relu(tf.nn.bias_add(conv, b3))
            if is_train:
                relu = tf.nn.dropout(relu, keep_prob=self.keep_prob)
            print(relu)


            flattened_convolution_size = int(relu.shape[1]) * int(relu.shape[2]) * int(relu.shape[3])
            print(flattened_convolution_size)
            flattened_convolution = features = tf.reshape(relu, [-1, flattened_convolution_size])

            if is_train:
                flattened_convolution =  tf.nn.dropout(flattened_convolution, keep_prob=self.keep_prob)

            W1 = tf.Variable(tf.truncated_normal([18*1*64, 32]))
            b4 = tf.Variable(tf.truncated_normal([32]))
            h1 = tf.nn.relu(tf.matmul(flattened_convolution, W1) + b4)


            W2 = tf.Variable(tf.truncated_normal([32, 2]))
            logits = tf.matmul(h1, W2)

            #self.accuracy = tf.metrics.accuracy(tf.argmax(self.Y, 1), tf.argmax(logits, 1))
            self.accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(self.Y, 1), tf.argmax(logits, 1)), tf.float32))
            self.confusion_matrix = tf.confusion_matrix(tf.argmax(self.Y, 1), tf.argmax(logits, 1))
            tf.summary.scalar('accuracy', self.accuracy)
            theta_D = [k1, b1, k2, b2, k3, b3, W1, b4, W2]           
            
            # D_prob = tf.nn.sigmoid(D_logit)

        self.loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=self.Y, logits=logits))
        tf.summary.scalar('loss', self.loss)
        # self.D_l2_loss = (0.0001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_D]) / len(theta_D))
        # self.D_loss = D_loss_real + D_loss_fake + self.D_l2_loss
        # self.G_l2_loss = (0.00001 * tf.add_n([tf.nn.l2_loss(t) for t in theta_G]) / len(theta_G))
        # self.G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.ones_like(D_logit_fake))) + self.G_l2_loss

        self.optimizer = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(self.loss)
        self.summary = tf.summary.merge_all()

# %% [markdown]
# ## Training the CNN

# %%
import os
import pandas as pd
# from cnn import CNN
import random
import tensorflow as tf
import xgboost as xgb
from sklearn.externals import joblib
from sklearn.metrics import confusion_matrix
#from plot_confusion_matrix import plot_confusion_matrix
#from plot_confusion_matrix import plot_confusion_matrix

random.seed(42)

class TrainCNN:

    def __init__(self, num_historical_days, days=10, pct_change=0):
        self.data = []
        self.labels = []
        self.test_data = []
        self.test_labels = []
        self.cnn = CNN(num_features=5, num_historical_days=num_historical_days, is_train=False)
#         files = [os.path.join('./stock_data', f) for f in os.listdir('./stock_data')]

        # Google Drive Method
        files = [f"{googlepath}stock_data/{f}" for f in os.listdir(f"{googlepath}stock_data")]
#         print(files)
    
    
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open','high','low','close','volume']]
            # data for new column labels that will use the pct_change of the closing data.
            # pct_change measure change between current and prior element. Map these into a 1x2
            # array to show if the pct_change > (our desired threshold) or less than.
            labels = df.close.pct_change(days).map(lambda x: [int(x > pct_change/100.0), int(x <= pct_change/100.0)])
            
            # rolling normalization. (df - df.mean) / (df.max - df.min)
            df = ((df -
            df.rolling(num_historical_days).mean().shift(-num_historical_days))
            /(df.rolling(num_historical_days).max().shift(-num_historical_days)
            -df.rolling(num_historical_days).min().shift(-num_historical_days)))
            df['labels'] = labels

            # doing pct_change will give some rows (like first row) a NaN value. Drop that.
            df = df.dropna()

            # Do the testing data split
            test_df = df[:365]
            df = df[400:]

            # get the predictors of the dataframe
            data = df[['open','high','low','close','volume']].values

            # the response value
            labels = df['labels'].values

            # start at num_historical_days and iterate the full length of the training
            # data at intervals of num_historical_days
            for i in range(num_historical_days, len(df), num_historical_days):
                # split the df into arrays of length num_historical_days and append
                # to data, i.e. array of df[curr - num_days : curr] -> a batch of values
                self.data.append(data[i-num_historical_days:i])

                # appending if price went up or down in curr day of "i" we are looking
                # at
                self.labels.append(labels[i-1])
            
            # do same for test data
            data = test_df[['open','high','low','close','volume']].values
            labels = test_df['labels'].values
            for i in range(num_historical_days, len(test_df), 1):
                self.test_data.append(data[i-num_historical_days:i])
                self.test_labels.append(labels[i-1])

    # a function to get a random_batch of data.
    def random_batch(self, batch_size=128):
        batch = []
        labels = []
        # zip concatenates each array index of both arrays together
        data = list(zip(self.data, self.labels))
        i = 0
        while True:
            i+= 1
            while True:
                # pick a random array, i.e. range of days, from data
                d = random.choice(data)
                # balance the data with equal number of positive pct_change
                # and negative pct_change
                if(d[1][0]== int(i%2)):
                    break
            batch.append(d[0])  # append the range of days we got to batch
            labels.append(d[1])  # append the label of that range of data we got
            if (len(batch) == batch_size):
                yield batch, labels
                batch = []
                labels = []

    def train(self, print_steps=100, display_steps=100, save_steps=SAVE_STEPS_AMOUNT, batch_size=128, keep_prob=0.6):
        if not os.path.exists(f'{googlepath}cnn_models'):
            os.makedirs(f'{googlepath}cnn_models')
        if not os.path.exists(f'{googlepath}logs'):
            os.makedirs(f'{googlepath}logs')
        if os.path.exists(f'{googlepath}logs/train'):
            for file in [os.path.join(f'{googlepath}logs/train/', f) for f in os.listdir(f'{googlepath}logs/train/')]:
                os.remove(file)
        if os.path.exists(f'{googlepath}logs/test'):
            for file in [os.path.join(f'{googlepath}logs/test/', f) for f in os.listdir(f'{googlepath}logs/test')]:
                os.remove(file)

        sess = tf.Session()
        loss = 0
        l2_loss = 0
        accuracy = 0
        saver = tf.train.Saver()
        train_writer = tf.summary.FileWriter(f'{googlepath}/logs/train')
        test_writer = tf.summary.FileWriter(f'{googlepath}/logs/test')
        sess.run(tf.global_variables_initializer())
        
        test_loss_array = []
        test_accuracy_array = []
        currentStep = "0"
        
        if os.path.exists(f'{googlepath}cnn_models/checkpoint'):
                with open(f'{googlepath}cnn_models/checkpoint', 'rb') as f:
                    model_name = next(f).split('"'.encode())[1]
                filename = "{}cnn_models/{}".format(googlepath, model_name.decode())
                currentStep = filename.split("-")[1]
                new_saver = tf.train.import_meta_graph('{}.meta'.format(filename))
                new_saver.restore(sess, "{}".format(filename))

        for i, [X, y] in enumerate(self.random_batch(batch_size)):

          
            _, loss_curr, accuracy_curr = sess.run([self.cnn.optimizer, self.cnn.loss, self.cnn.accuracy], feed_dict=
                    {self.cnn.X:X, self.cnn.Y:y, self.cnn.keep_prob:keep_prob})
            loss += loss_curr
            accuracy += accuracy_curr
            if (i+1) % print_steps == 0:
                print('Step={} loss={}, accuracy={}'.format(i + int(currentStep), loss/print_steps, accuracy/print_steps))
                loss = 0
                l2_loss = 0
                accuracy = 0
                test_loss, test_accuracy, confusion_matrix = sess.run([self.cnn.loss, self.cnn.accuracy, self.cnn.confusion_matrix], feed_dict={self.cnn.X:self.test_data, self.cnn.Y:self.test_labels, self.cnn.keep_prob:1})
                test_loss_array.append(test_loss)
                test_accuracy_array.append(test_accuracy)
                print("Test loss = {}, Test accuracy = {}".format(test_loss, test_accuracy))
            if (i+1) % save_steps == 0:
                saver.save(sess,  f'{googlepath}cnn_models/cnn.ckpt', i)

            if (i+1) % display_steps == 0:
                summary = sess.run(self.cnn.summary, feed_dict=
                    {self.cnn.X:X, self.cnn.Y:y, self.cnn.keep_prob:keep_prob})
                train_writer.add_summary(summary, i)
                summary = sess.run(self.cnn.summary, feed_dict={
                    self.cnn.X:self.test_data, self.cnn.Y:self.test_labels, self.cnn.keep_prob:1})
                test_writer.add_summary(summary, i)
            
            # end training at training_amount epochs
            if (i + int(currentStep)) > TRAINING_AMOUNT:
                print("Reached {} epochs for CNN".format(i + int(currentStep)))
                sess.close()
                #print(confusion_matrix)
                #plot_confusion_matrix(confusion_matrix, ['Down', 'Up'], normalize=True, title="CNN Confusion Matrix")
                
                axisX = np.arange(0,len(test_loss_array),1)
                plt.plot(axisX, test_loss_array, label='test loss')
                plt.plot(axisX, test_accuracy_array, label='test accuracy')
                plt.legend()
                plt.title('test loss and accuracy')
                plt.show()

                break


# if __name__ == '__main__':
tf.reset_default_graph()
cnn = TrainCNN(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
cnn.train()
#print(confusion_matrix)
# Out:
# Tensor("cnn/Relu:0", shape=(?, 20, 1, 16), dtype=float32)
# Tensor("cnn/Relu_1:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("cnn/Relu_2:0", shape=(?, 18, 1, 64), dtype=float32)
# 1152
# WARNING:tensorflow:From <ipython-input-9-3ac5478d33d2>:73: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANDV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANTM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AJG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/T.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AZO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHGE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BRK.B.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BIIB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BKNG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BWA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BMY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHRW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CDNS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CPB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBOE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CELG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CERN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CINF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/C.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTXS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTSH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMCSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CXO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ED.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GLW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COTY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSRA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DFS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/D.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DWDP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DTE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EBAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ECL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EVHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FFIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FAST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FRT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FITB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FISV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLIR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/F.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FBHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GRMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GILD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GWW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSIC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HLT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBAN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HII.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IDXX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INFO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ITW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ILMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INCY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ICE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IBM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IFF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ISRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IVZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IQV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JBHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SJM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNJ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JPM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/K.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KEY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KIM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KLAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LRCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LKQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/L.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LOW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LYB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/M.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MLM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MKC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MGM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KORS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCHP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSFT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MHK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDLZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MNST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NDAQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NAVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NLSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NBL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JWN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NSC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NCLH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NUE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NVDA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OXY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PAYX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PYPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PBCT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PXD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PGR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PLD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PHM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PVH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QRVO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QCOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PWR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DGX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RRC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RJF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RTN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/O.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RSG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPGI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWKS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBUX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SIVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TROW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TTWO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TGT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TIF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TWX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TJX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TDG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRIP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOXA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/USB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UDR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ULTA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/URI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VLO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VIAB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/V.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VNO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WBA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WELL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WDC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WLTW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYNN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XLNX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/YUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZBH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZION.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZTS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABBV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ACN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ATVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AYI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADBE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AFL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/A.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AKAM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALLE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOGL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMZN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADI.csv
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/cnn_models/cnn.ckpt-49999
# Reached 50001 epochs for CNN

# %% [markdown]
# # Train XGB Boost

# %%
import os
import pandas as pd
# from gan import GAN
import random
import tensorflow as tf
import xgboost as xgb
from sklearn.externals import joblib
from sklearn.metrics import confusion_matrix
# from plot_confusion_matrix import plot_confusion_matrix

# os.environ["CUDA_VISIBLE_DEVICES"]=""

class TrainXGBBoost:

    def __init__(self, num_historical_days, days=10, pct_change=0):
        self.data = []
        self.labels = []
        self.test_data = []
        self.test_labels = []
        
        assert os.path.exists(f'{googlepath}models/checkpoint')
        gan = GAN(num_features=5, num_historical_days=num_historical_days,
                        generator_input_size=200, is_train=False)
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            if os.path.exists(f'{googlepath}models/checkpoint'):
                    
                    with open(f'{googlepath}models/checkpoint', 'rb') as f:
                        model_name = next(f).split('"'.encode())[1]
                    filename = "{}models/{}".format(googlepath, model_name.decode())
                    currentStep = filename.split("-")[1]
                    new_saver = tf.train.import_meta_graph('{}.meta'.format(filename))
                    new_saver.restore(sess, "{}".format(filename))
            files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}/stock_data')]
            for file in files:
                print(file)
                #Read in file -- note that parse_dates will be need later
                df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
                df = df[['open','high','low','close','volume']]
                # #Create new index with missing days
                # idx = pd.date_range(df.index[-1], df.index[0])
                # #Reindex and fill the missing day with the value from the day before
                # df = df.reindex(idx, method='bfill').sort_index(ascending=False)
                #Normilize using a of size num_historical_days
                labels = df.close.pct_change(days).map(lambda x: int(x > pct_change/100.0))
                df = ((df -
                df.rolling(num_historical_days).mean().shift(-num_historical_days))
                /(df.rolling(num_historical_days).max().shift(-num_historical_days)
                -df.rolling(num_historical_days).min().shift(-num_historical_days)))
                df['labels'] = labels
                #Drop the last 10 day that we don't have data for
                df = df.dropna()
                #Hold out the last year of trading for testing
                test_df = df[:365]
                #Padding to keep labels from bleeding
                df = df[400:]
                #This may not create good samples if num_historical_days is a
                #mutliple of 7
                data = df[['open','high','low','close','volume']].values
                labels = df['labels'].values
                for i in range(num_historical_days, len(df), num_historical_days):
                    features = sess.run(gan.features, feed_dict={gan.X:[data[i-num_historical_days:i]]})
                    self.data.append(features[0])
#                     print(features[0])
                    self.labels.append(labels[i-1])
                data = test_df[['open','high','low','close','volume']].values
                labels = test_df['labels'].values
                for i in range(num_historical_days, len(test_df), 1):
                    features = sess.run(gan.features, feed_dict={gan.X:[data[i-num_historical_days:i]]})
                    self.test_data.append(features[0])
                    self.test_labels.append(labels[i-1])



    def train(self):
        params = {}
        params['objective'] = 'multi:softprob'
        params['eta'] = 0.01 # The training step in each iteration
        params['num_class'] = 2 # Number of classe in the dataset
        params['max_depth'] = 20 # Max depth in each tree
        params['subsample'] = 0.05 
        params['colsample_bytree'] = 0.05
        params['eval_metric'] = 'mlogloss' 
        #params['scale_pos_weight'] = 10
        #params['silent'] = True
        #params['gpu_id'] = 0
        #params['max_bin'] = 16
        #params['tree_method'] = 'gpu_hist'

        train = xgb.DMatrix(self.data, self.labels)
        test = xgb.DMatrix(self.test_data, self.test_labels)

        watchlist = [(train, 'train'), (test, 'test')]
        clf = xgb.train(params, train, 1000, evals=watchlist, early_stopping_rounds=100)
        joblib.dump(clf, f'{googlepath}models/clf.pkl')
        # cm = confusion_matrix(self.test_labels, map(lambda x: int(x[1] > .5), clf.predict(test)))
        cm = confusion_matrix(self.test_labels, list(map(lambda x: int(x[1] > .5), clf.predict(test)))) # 
        print(cm)
        plot_confusion_matrix(cm, ['Down', 'Up'], normalize=True, title="Confusion Matrix")

tf.reset_default_graph()
boost_model = TrainXGBBoost(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
boost_model.train()
# Out:
# Tensor("Relu:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_1:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_2:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# Tensor("Relu_4:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_5:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_6:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/models/gan.ckpt-49999
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANDV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANTM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AJG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/T.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AZO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHGE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BRK.B.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BIIB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BKNG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BWA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BMY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHRW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CDNS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CPB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBOE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CELG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CERN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CINF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/C.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTXS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTSH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMCSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CXO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ED.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GLW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COTY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSRA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DFS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/D.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DWDP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DTE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EBAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ECL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EVHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FFIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FAST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FRT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FITB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FISV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLIR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/F.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FBHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GRMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GILD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GWW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSIC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HLT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBAN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HII.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IDXX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INFO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ITW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ILMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INCY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ICE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IBM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IFF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ISRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IVZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IQV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JBHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SJM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNJ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JPM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/K.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KEY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KIM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KLAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LRCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LKQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/L.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LOW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LYB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/M.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MLM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MKC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MGM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KORS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCHP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSFT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MHK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDLZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MNST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NDAQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NAVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NLSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NBL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JWN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NSC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NCLH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NUE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NVDA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OXY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PAYX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PYPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PBCT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PXD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PGR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PLD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PHM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PVH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QRVO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QCOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PWR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DGX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RRC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RJF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RTN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/O.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RSG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPGI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWKS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBUX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SIVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TROW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TTWO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TGT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TIF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TWX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TJX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TDG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRIP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOXA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/USB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UDR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ULTA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/URI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VLO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VIAB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/V.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VNO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WBA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WELL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WDC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WLTW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYNN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XLNX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/YUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZBH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZION.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZTS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABBV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ACN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ATVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AYI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADBE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AFL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/A.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AKAM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALLE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOGL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMZN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADI.csv
# [0]	train-mlogloss:0.691847	test-mlogloss:0.692166
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.690627	test-mlogloss:0.691296
# [2]	train-mlogloss:0.689526	test-mlogloss:0.690539
# [3]	train-mlogloss:0.688315	test-mlogloss:0.689668
# [4]	train-mlogloss:0.686967	test-mlogloss:0.688663
# [5]	train-mlogloss:0.68575	test-mlogloss:0.687798
# [6]	train-mlogloss:0.684741	test-mlogloss:0.687091
# [7]	train-mlogloss:0.68367	test-mlogloss:0.686369
# [8]	train-mlogloss:0.682558	test-mlogloss:0.685611
# [9]	train-mlogloss:0.681476	test-mlogloss:0.684838
# [10]	train-mlogloss:0.680672	test-mlogloss:0.684357
# [11]	train-mlogloss:0.67972	test-mlogloss:0.683709
# [12]	train-mlogloss:0.678877	test-mlogloss:0.683158
# [13]	train-mlogloss:0.677775	test-mlogloss:0.68237
# [14]	train-mlogloss:0.676801	test-mlogloss:0.681722
# [15]	train-mlogloss:0.675829	test-mlogloss:0.681094
# [16]	train-mlogloss:0.674737	test-mlogloss:0.680346
# [17]	train-mlogloss:0.673862	test-mlogloss:0.679746
# [956]	train-mlogloss:0.423786	test-mlogloss:0.59684
# [957]	train-mlogloss:0.423686	test-mlogloss:0.596851
# [958]	train-mlogloss:0.423538	test-mlogloss:0.596821
# [959]	train-mlogloss:0.423371	test-mlogloss:0.596818
# [960]	train-mlogloss:0.423231	test-mlogloss:0.596772
# [961]	train-mlogloss:0.423114	test-mlogloss:0.596744
# [962]	train-mlogloss:0.422975	test-mlogloss:0.596739
# [963]	train-mlogloss:0.422794	test-mlogloss:0.596678
# [964]	train-mlogloss:0.422605	test-mlogloss:0.596618
# [965]	train-mlogloss:0.422454	test-mlogloss:0.596582
# [966]	train-mlogloss:0.422336	test-mlogloss:0.596559
# [967]	train-mlogloss:0.422186	test-mlogloss:0.596547
# [968]	train-mlogloss:0.422042	test-mlogloss:0.596529
# [969]	train-mlogloss:0.42186	test-mlogloss:0.596513
# [970]	train-mlogloss:0.421682	test-mlogloss:0.596455
# [971]	train-mlogloss:0.421571	test-mlogloss:0.596455
# [972]	train-mlogloss:0.421447	test-mlogloss:0.596468
# [973]	train-mlogloss:0.421261	test-mlogloss:0.596398
# [974]	train-mlogloss:0.421127	test-mlogloss:0.596397
# [975]	train-mlogloss:0.42096	test-mlogloss:0.596321
# [976]	train-mlogloss:0.420735	test-mlogloss:0.596252
# [977]	train-mlogloss:0.420626	test-mlogloss:0.596226
# [978]	train-mlogloss:0.420461	test-mlogloss:0.596229
# [979]	train-mlogloss:0.420293	test-mlogloss:0.596229
# [980]	train-mlogloss:0.420118	test-mlogloss:0.59618
# [981]	train-mlogloss:0.41997	test-mlogloss:0.596151
# [982]	train-mlogloss:0.419848	test-mlogloss:0.596139
# [983]	train-mlogloss:0.419748	test-mlogloss:0.596141
# [984]	train-mlogloss:0.419603	test-mlogloss:0.596117
# [985]	train-mlogloss:0.419438	test-mlogloss:0.596079
# [986]	train-mlogloss:0.419286	test-mlogloss:0.596065
# [987]	train-mlogloss:0.419113	test-mlogloss:0.596048
# [988]	train-mlogloss:0.418981	test-mlogloss:0.596028
# [989]	train-mlogloss:0.418881	test-mlogloss:0.596028
# [990]	train-mlogloss:0.418772	test-mlogloss:0.596006
# [991]	train-mlogloss:0.418601	test-mlogloss:0.595976
# [992]	train-mlogloss:0.418429	test-mlogloss:0.595909
# [993]	train-mlogloss:0.418311	test-mlogloss:0.595909
# [994]	train-mlogloss:0.418175	test-mlogloss:0.595925
# [995]	train-mlogloss:0.418015	test-mlogloss:0.595915
# [996]	train-mlogloss:0.417843	test-mlogloss:0.595879
# [997]	train-mlogloss:0.417685	test-mlogloss:0.595855
# [998]	train-mlogloss:0.417578	test-mlogloss:0.595862
# [999]	train-mlogloss:0.417464	test-mlogloss:0.59584
# [[55465 34031]
#  [22943 61038]]
# Normalized confusion matrix
# [[0.61974837 0.38025163]
#  [0.27319275 0.72680725]]

# %% [markdown]
# ## Change the names of the files in the deployed_model folder
#
# Directions: Run after training and placing the GAN checkpoints you desire into the deployed_models folder. Then thisd code will rename all of them so that they run for the "Get the Predictions" section.

# %%
import os

# Below Code Gets Rid of Copy Of when making a copy of the models.
for filename in os.listdir(f'{googlepath}deployed_model/'):
    split = filename.split(" ")
    if len(split) == 3:
        os.rename(f'{googlepath}deployed_model/{filename}', f'{googlepath}deployed_model/{split[2]}')
    else:
        print("Nothing to rename.")

# Below Code Gets Rid of Checkpoint Number in Name
for filename in os.listdir(f'{googlepath}deployed_model/'):
    split = filename.split(".")
    if len(split) == 3:
        prefix, _, suffix = split
        new_name = prefix + "." + suffix
        os.rename(f'{googlepath}deployed_model/{filename}', f'{googlepath}deployed_model/{new_name}')
    elif filename == "clf.pkl":
        os.rename(f'{googlepath}deployed_model/{filename}', f'{googlepath}deployed_model/xgb')
    else:
        print("Nothing to rename.")
# Out:
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.

# %% [markdown]
# # Get the Predictions

# %%
import os
import pandas as pd
# from gan import GAN
import random
import tensorflow as tf
import xgboost as xgb
from sklearn.externals import joblib


# os.environ["CUDA_VISIBLE_DEVICES"]=""

class Predict:

    def __init__(self, num_historical_days=20, days=10, pct_change=0, 
                 gan_model=f'{googlepath}deployed_model/gan', 
                 cnn_model=f'{googlepath}deployed_model/cnn', 
                 xgb_model=f'{googlepath}deployed_model/xgb'):
        self.data = []
        self.num_historical_days = num_historical_days
        self.gan_model = gan_model
        self.cnn_model = cnn_model
        self.xgb_model = xgb_model
        # assert os.path.exists(gan_model)
        # assert os.path.exists(cnn_modle)
        # assert os.path.exists(xgb_model)

        files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}stock_data')]
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df.sort_index(ascending=False)
            df = df[['open', 'high', 'low', 'close', 'volume']]
            df = ((df -
                  df.rolling(num_historical_days).mean().shift(-num_historical_days)) /
                  (df.rolling(num_historical_days).max().shift(-num_historical_days) -
                  df.rolling(num_historical_days).min().shift(-num_historical_days)))
            df = df.dropna()

            """
            file.split --> is the symbol of the current file. Append a tuple of
            that symbol and the dataframe index[0] which is the timestamp, and
            thirdly append the data for 200 to 200 + num_historical_days values
            (open, high, low, close, volume). For each symbol we have, we are
            predicting based on the df[200:200+num_historical_days].values...
            """
            self.data.append((file.split('/')[-1], df.index[0], df[200:200+num_historical_days].values))
            
#         print("Data: ", self.data)


    def gan_predict(self):
        # clears the default graph stack and resets the global default graph.

        tf.reset_default_graph() 
        gan = GAN(num_features=5, num_historical_days=self.num_historical_days,
                  generator_input_size=200, is_train=False)
        # A class for running Tensorflow operations. A session object
        # encapsulates the environment in which Operation objects are executed,
        # and Tensor objects are evaluated. A session may own resources, such as
        # tf.Variable, tf.QueueBase and tf.ReaderBase. It is important to
        # release these resources when they are no longer required. Invoke
        # tf.Session.close method on the session or use the session as a context
        # manager. 
        # with tf.Session() as sess:
        #   sess.run(...)
        # or
        # sess = tf.Session()
        # sess.run(...)
        # sess.close()     
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            saver.restore(sess, self.gan_model)
            # Reconstruct a Python object from a file persisted with joblib.dump
            clf = joblib.load(self.xgb_model)
            for sym, date, data in self.data:
                # run takes in feed_dict=None, session=None. A feed_dict is a
                # dictionary that maps Tensor objects to feed values. In this
                # case, I believe we are doing run( fetches, feed_dict=None...)
                # case where the fetches is gan.features and the feed_dict
                # points to the gan.X dictionary which points to data. The
                # fetches argument may be a single graph element, or an
                # arbitrarily nested list, tuple, namedtuple, dict, or
                # OrderedDict containing graph elements at its leaves.
#                 print("data: ", data)
#                 print("data length: ", len(data))
#                 print("gan features: ", gan.features)
                features = sess.run(gan.features, feed_dict={gan.X:[data]})
                # Value returned by run() has the same shape as the fetches
                # argument, where the leaves are replaced by the corresponding
                # values returned by TensorFlow.  
                
                # xgb.DMatrix, construct one from either a dense matrix, a
                # sparse matrix, or a local file. Supported input file formats
                # are either a libsvm text file or a binary file that was
                # created previously by xgb.DMatrix.save. Internal data
                # structure that is used by XGBoost which is optimized for both
                # memory efficiency and training speed.
                features = xgb.DMatrix(features)
                

                # The clf predict is the xgb classifier that is used on the gan
                # features (the flattened last layer of the convolutional neural
                # network, that is the discriminator). As far as I can tell, we
                # are using the GAN on the past 20 days to come up with some
                # features. Then these features are plugged into the XGBoost
                # Classifier. Then the XGBoost Classifier makes a prediction for
                # the stock (going Up or Down).
                print('{} {} {}'.format(str(date).split(' ')[0], sym, clf.predict(features)[0][1] > 0.5))


# if __name__ == '__main__':
p = Predict(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
p.gan_predict()
# Out:
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANDV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ANTM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AJG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/T.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AZO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHGE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BAX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BRK.B.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BBY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BIIB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BLK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BKNG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BWA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BHF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BMY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AVGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHRW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CDNS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CPB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBOE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CBS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CELG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CERN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CHD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CINF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/C.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTXS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CTSH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMCSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CAG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CXO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ED.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GLW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COTY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSRA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CVS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DVN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DFS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DISH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DLTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/D.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DWDP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DTE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EBAY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ECL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EMR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ETR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EVHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQIX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EQR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXPD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ESRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/EXR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FFIV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FAST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FRT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FDX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FITB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FISV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLIR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FLR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/F.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FBHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GRMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GILD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GPN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GWW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HCP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSIC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HLT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HOLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HRL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HPQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HBAN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HII.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IDXX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INFO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ITW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ILMN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INCY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ICE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IBM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IFF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/INTU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ISRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IVZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IPGP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IQV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/IRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JBHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SJM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNJ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JCI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JPM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JNPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/K.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KEY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KIM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KMI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KLAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KHC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LRCX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LEN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LKQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/L.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LOW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LYB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/M.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MPC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MLM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MKC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MTD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MGM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/KORS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCHP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSFT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MHK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MDLZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MON.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MNST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MSI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NDAQ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NAVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NFX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NWS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NLSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NBL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/JWN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NSC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NTRS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NOC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NCLH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NRG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NUE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/NVDA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORLY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OXY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/OKE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ORCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PAYX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PYPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PBCT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PKI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRGO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PXD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PNC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PPL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PFG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PGR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PLD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PRU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PEG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PSA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PHM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PVH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QRVO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/QCOM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/PWR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DGX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RRC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RJF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RTN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/O.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/REGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RSG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RHI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ROST.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/RCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPGI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CRM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBAC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SCG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SHW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SPG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWKS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SLG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LUV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SBUX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SRCL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/STI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SIVB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SNPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/SYY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TROW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TTWO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TPR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TGT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FTI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TXT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/BK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/CLX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/COO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/HSY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/DIS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TIF.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TWX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TJX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TMK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSCO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TDG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TRIP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOXA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/FOX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/TSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/USB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UDR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ULTA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UPS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/URI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UHS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/UNM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VLO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VAR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VTR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRSK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VZ.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VRTX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VIAB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/V.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VNO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/VMC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WBA.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WAT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WEC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WFC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WELL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WDC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WU.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WRK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WY.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WHR.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WMB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WLTW.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/WYNN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XEL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XRX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XLNX.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/XYL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/YUM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZBH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZION.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ZTS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MMM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AOS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABBV.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ACN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ATVI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AYI.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADBE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AES.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AET.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AFL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/A.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APD.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AKAM.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALB.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ARE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALXN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALLE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADS.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/LNT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ALL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOGL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/GOOG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/MO.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMZN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEE.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AAL.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AEP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AXP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AIG.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMT.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AWK.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMP.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ABC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AME.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/AMGN.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APH.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/APC.csv
# drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/stock_data/ADI.csv
# Tensor("Relu:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_1:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_2:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# Tensor("Relu_4:0", shape=(?, 20, 1, 32), dtype=float32)
# Tensor("Relu_5:0", shape=(?, 20, 1, 64), dtype=float32)
# Tensor("Relu_6:0", shape=(?, 18, 1, 128), dtype=float32)
# 2304
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/deployed_model/gan
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# DataLossError: Unable to open table file drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/deployed_model/gan: Failed precondition: drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/deployed_model/gan; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
# 	 [[{{node save/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# DataLossError                             Traceback (most recent call last)
# <ipython-input-11-21b86a6800a0> in <module>()
#     112 # if __name__ == '__main__':
#     113 p = Predict(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
# --> 114 p.gan_predict()
#
# <ipython-input-11-21b86a6800a0> in gan_predict(self)
#      71             sess.run(tf.global_variables_initializer())
#      72             saver = tf.train.Saver()
# ---> 73             saver.restore(sess, self.gan_model)
#      74             # Reconstruct a Python object from a file persisted with joblib.dump
#      75             clf = joblib.load(self.xgb_model)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py in restore(self, sess, save_path)
#    1288       else:
#    1289         sess.run(self.saver_def.restore_op_name,
# -> 1290                  {self.saver_def.filename_tensor_name: save_path})
#    1291     except errors.NotFoundError as err:
#    1292       # There are three common conditions that might cause this error:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# DataLossError: Unable to open table file drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/deployed_model/gan: Failed precondition: drive/My Drive/Colab Notebooks/CS230_PROJECT/GAN/deployed_model/gan; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
# 	 [[node save/RestoreV2 (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
#
# Original stack trace for 'save/RestoreV2':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2828, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-11-21b86a6800a0>", line 114, in <module>
#     p.gan_predict()
#   File "<ipython-input-11-21b86a6800a0>", line 72, in gan_predict
#     saver = tf.train.Saver()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 828, in __init__
#     self.build()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
